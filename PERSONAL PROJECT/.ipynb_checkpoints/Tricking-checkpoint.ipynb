# %% [markdown]
# # Tricking Stats

# %%
import pandas as pd
tricking = pd.read_csv('Tricking.csv')
tricking
# Out:
#            Date                 Trick_Name  Attempts  Landed_Count  \
# 0    2025-09-25                      Fulls         3             3
# 1    2025-09-25             Full Hyperhook         7             7
# 2    2025-09-25                Double Full         7             6
# 3    2025-09-25                      Corks         3             3
# 4    2025-09-25                 Cheat 1080         2             2
# ..          ...                        ...       ...           ...
# 131  2025-11-25  Full Hyperhook (Shuriken)         1             1
# 132  2025-11-25                Double Full         2             2
# 133  2025-11-25      Double Full Hyperhook         1             0
# 134  2025-11-25                Triple Full         6             0
# 135  2025-11-25            Back Handspring         1             1
#
#           Surface
# 0    Spring Floor
# 1    Spring Floor
# 2    Spring Floor
# 3    Spring Floor
# 4    Spring Floor
# ..            ...
# 131           NaN
# 132           NaN
# 133           NaN
# 134           NaN
# 135           NaN
#
# [136 rows x 5 columns]

# %%
tricking['Trick_Name'].unique()
# Out:
# array(['Fulls', 'Full Hyperhook', 'Double Full', 'Corks', 'Cheat 1080',
#        'Double B-Twist', 'Cheat 900', 'Gainer', 'Corks (Round)',
#        'Round Off Backflip (Multiple Kicks)', 'Double Full Hyperhook',
#        'Full Snapu', 'B-Twist Hyperhook', 'B-Twist', 'Double Cork',
#        'Round Off Backflip', 'Boxcutter', 'Full Hyperhook (Shuriken)',
#        'Triple Full', 'B-Twist (Shuriken)', 'Front Tuck',
#        'Back Handspring', 'Wrap Full', 'Wrap Full Hyperhook',
#        'Backside 1260', 'Round Off Backflip ', 'Side Swipe',
#        'Gainer (Switch)'], dtype=object)

# %% [markdown]
# ### Tricks I've done most often

# %%
tricking['Trick_Name'].value_counts().head() # Value
# Out:
# Trick_Name
# Full Hyperhook    15
# Fulls             13
# Corks             13
# Cheat 1080        10
# Double Full        9
# Name: count, dtype: int64

# %%
tricking['Trick_Name'].value_counts(normalize = True).head() # Percentage
# Out:
# Trick_Name
# Full Hyperhook    0.110294
# Fulls             0.095588
# Corks             0.095588
# Cheat 1080        0.073529
# Double Full       0.066176
# Name: proportion, dtype: float64

# %% [markdown]
# ### Show tricks that I didn't land 100% of the time

# %%
nlanded100 = tricking['Attempts'] != tricking['Landed_Count']
tricking[nlanded100].head()
# Out:
#           Date                           Trick_Name  Attempts  Landed_Count  \
# 2   2025-09-25                          Double Full         7             6
# 7   2025-09-28                       Double B-Twist         3             0
# 11  2025-10-05                        Corks (Round)         7             5
# 12  2025-10-05                           Cheat 1080         5             3
# 22  2025-10-08  Round Off Backflip (Multiple Kicks)         3             2
#
#          Surface
# 2   Spring Floor
# 7   Spring Floor
# 11  Spring Floor
# 12  Spring Floor
# 22   Puzzle Mats

# %%
tricking['Attempts'].describe()
# Out:
# count    136.000000
# mean       2.294118
# std        1.963058
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        3.000000
# max       16.000000
# Name: Attempts, dtype: float64

# %%
tricking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          108 non-null    object
#  1   Trick_Name    108 non-null    object
#  2   Attempts      108 non-null    int64
#  3   Landed_Count  108 non-null    int64
#  4   Surface       108 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 4.3+ KB
